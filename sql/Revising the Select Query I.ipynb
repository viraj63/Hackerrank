# %%
import pandas as pd
import sqlite3

# %%
#pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Collecting sqlparse
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.2/41.2 kB 1.9 MB/s eta 0:00:00
# Collecting prettytable
#   Downloading prettytable-3.8.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: ipython-genutils in c:\users\viraj\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Collecting sqlalchemy>=2.0
#   Downloading SQLAlchemy-2.0.18-cp39-cp39-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\viraj\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython in c:\users\viraj\anaconda3\lib\site-packages (from ipython-sql) (8.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\viraj\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\viraj\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (1.1.1)
# Requirement already satisfied: decorator in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.2)
# Requirement already satisfied: colorama in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: backcall in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\viraj\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.20)
# Requirement already satisfied: wcwidth in c:\users\viraj\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\viraj\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\viraj\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing in c:\users\viraj\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\viraj\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Installing collected packages: sqlparse, sqlalchemy, prettytable, ipython-sql
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.32
#     Uninstalling SQLAlchemy-1.4.32:
#       Successfully uninstalled SQLAlchemy-1.4.32
# Successfully installed ipython-sql-0.5.0 prettytable-3.8.0 sqlalchemy-2.0.18 sqlparse-0.4.4
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\viraj\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Query all columns for all American cities in the CITY table with populations larger than 100000. The CountryCode for America is USA.

# %% [markdown]
# ![1449729804-f21d187d0f-CITY.jpg](attachment:1449729804-f21d187d0f-CITY.jpg)

# %%
SELECT *
FROM CITY
WHERE CountryCode = 'USA' AND Population > 100000;
